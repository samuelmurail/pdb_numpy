# %%
import sys
import os
import numpy as np
from copy import deepcopy

sys.path.insert(0, os.path.abspath('./src/'))

from pdb_numpy import Coor, Model, format, abinitio

# %%
file_in = '../BeEM/example_input/3j6b.cif'
test = Coor(file_in)
test.write("tmp.pdb", overwrite=True)
# Out:
# EMDB EMD-2566 'Electron cryo-microscopy of yeast mitochondrial large ribosomal subunit' 'associated EM volume'
#
# ['EMDB', 'EMD-2566', "'Electron cryo-microscopy of yeast mitochondrial large ribosomal subunit'", "'associated EM volume'"]
# ['EMDB', 'EMD-2566', "'Electron", 'cryo-microscopy', 'of', 'yeast', 'mitochondrial', 'large', 'ribosomal', "subunit'", "'associated", 'EM', "volume'"]
# PDB  3J6B     .                                                                         'complete structure'
#
# ['PDB', '3J6B', '.', "'complete structure'"]
# ['PDB', '3J6B', '.', "'complete", "structure'"]
# PDB  1VW3     'yeast mitochondrial large ribosomal subunit split 1'                     split
#
# ['PDB', '1VW3', "'yeast mitochondrial large ribosomal subunit split 1'", 'split']
# ['PDB', '1VW3', "'yeast", 'mitochondrial', 'large', 'ribosomal', 'subunit', 'split', "1'", 'split']
# PDB  1VW4     'yeast mitochondrial large ribosomal subunit split 2'                     split
#
# ['PDB', '1VW4', "'yeast mitochondrial large ribosomal subunit split 2'", 'split']
# ['PDB', '1VW4', "'yeast", 'mitochondrial', 'large', 'ribosomal', 'subunit', 'split', "2'", 'split']
# 'Amunts, A.'       1
#
# ["'Amunts, A.'", '1']
# ["'Amunts,", "A.'", '1']
# 'Brown, A.'        2
#
# ["'Brown, A.'", '2']
# ["'Brown,", "A.'", '2']
# 'Bai, X.C.'        3
#
# ["'Bai, X.C.'", '3']
# ["'Bai,", "X.C.'", '3']
# 'Llacer, J.L.'     4
#
# ["'Llacer, J.L.'", '4']
# ["'Llacer,", "J.L.'", '4']
# 'Hussain, T.'      5
#
# ["'Hussain, T.'", '5']
# ["'Hussain,", "T.'", '5']
# 'Emsley, P.'       6
#
# ["'Emsley, P.'", '6']
# ["'Emsley,", "P.'", '6']
# 'Long, F.'         7
#
# ["'Long, F.'", '7']
# ["'Long,", "F.'", '7']
# 'Murshudov, G.'    8
#
# ["'Murshudov, G.'", '8']
# ["'Murshudov,", "G.'", '8']
# 'Scheres, S.H.W.'  9
#
# ["'Scheres, S.H.W.'", '9']
# ["'Scheres,", "S.H.W.'", '9']
# 'Ramakrishnan, V.' 10
#
# ["'Ramakrishnan, V.'", '10']
# ["'Ramakrishnan,", "V.'", '10']
# primary 'Amunts, A.'       1
#
# ['primary', "'Amunts, A.'", '1']
# ['primary', "'Amunts,", "A.'", '1']
# primary 'Brown, A.'        2
#
# ['primary', "'Brown, A.'", '2']
# ['primary', "'Brown,", "A.'", '2']
# primary 'Bai, X.C.'        3
#
# ['primary', "'Bai, X.C.'", '3']
# ['primary', "'Bai,", "X.C.'", '3']
# primary 'Llacer, J.L.'     4
#
# ['primary', "'Llacer, J.L.'", '4']
# ['primary', "'Llacer,", "J.L.'", '4']
# primary 'Hussain, T.'      5
#
# ['primary', "'Hussain, T.'", '5']
# ['primary', "'Hussain,", "T.'", '5']
# primary 'Emsley, P.'       6
#
# ['primary', "'Emsley, P.'", '6']
# ['primary', "'Emsley,", "P.'", '6']
# primary 'Long, F.'         7
#
# ['primary', "'Long, F.'", '7']
# ['primary', "'Long,", "F.'", '7']
# primary 'Murshudov, G.'    8
#
# ['primary', "'Murshudov, G.'", '8']
# ['primary', "'Murshudov,", "G.'", '8']
# primary 'Scheres, S.H.'    9
#
# ['primary', "'Scheres, S.H.'", '9']
# ['primary', "'Scheres,", "S.H.'", '9']
# primary 'Ramakrishnan, V.' 10
#
# ['primary', "'Ramakrishnan, V.'", '10']
# ['primary', "'Ramakrishnan,", "V.'", '10']
# 1  polymer     nat '21S ribosomal RNA'                                1057805.375 1   ? ? ? ?
#
# ['1', 'polymer', 'nat', "'21S ribosomal RNA'", '1057805.375', '1', '?', '?', '?', '?']
# ['1', 'polymer', 'nat', "'21S", 'ribosomal', "RNA'", '1057805.375', '1', '?', '?', '?', '?']
# 2  polymer     nat '54S ribosomal protein RML2, mitochondrial'        43870.023   1   ? ? ? ?
#
# ['2', 'polymer', 'nat', "'54S ribosomal protein RML2, mitochondrial'", '43870.023', '1', '?', '?', '?', '?']
# ['2', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'RML2,', "mitochondrial'", '43870.023', '1', '?', '?', '?', '?']
# 3  polymer     nat '54S ribosomal protein L9, mitochondrial'          29843.547   1   ? ? ? ?
#
# ['3', 'polymer', 'nat', "'54S ribosomal protein L9, mitochondrial'", '29843.547', '1', '?', '?', '?', '?']
# ['3', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L9,', "mitochondrial'", '29843.547', '1', '?', '?', '?', '?']
# 4  polymer     nat '54S ribosomal protein YmL6, mitochondrial'        32014.609   1   ? ? ? ?
#
# ['4', 'polymer', 'nat', "'54S ribosomal protein YmL6, mitochondrial'", '32014.609', '1', '?', '?', '?', '?']
# ['4', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'YmL6,', "mitochondrial'", '32014.609', '1', '?', '?', '?', '?']
# 5  polymer     nat '54S ribosomal protein L7, mitochondrial'          33152.031   1   ? ? ? ?
#
# ['5', 'polymer', 'nat', "'54S ribosomal protein L7, mitochondrial'", '33152.031', '1', '?', '?', '?', '?']
# ['5', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L7,', "mitochondrial'", '33152.031', '1', '?', '?', '?', '?']
# 6  polymer     nat '54S ribosomal protein L6, mitochondrial'          23926.887   1   ? ? ? ?
#
# ['6', 'polymer', 'nat', "'54S ribosomal protein L6, mitochondrial'", '23926.887', '1', '?', '?', '?', '?']
# ['6', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L6,', "mitochondrial'", '23926.887', '1', '?', '?', '?', '?']
# 7  polymer     nat '54S ribosomal protein L50, mitochondrial'         16313.828   1   ? ? ? ?
#
# ['7', 'polymer', 'nat', "'54S ribosomal protein L50, mitochondrial'", '16313.828', '1', '?', '?', '?', '?']
# ['7', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L50,', "mitochondrial'", '16313.828', '1', '?', '?', '?', '?']
# 8  polymer     nat '54S ribosomal protein L23, mitochondrial'         18499.500   1   ? ? ? ?
#
# ['8', 'polymer', 'nat', "'54S ribosomal protein L23, mitochondrial'", '18499.500', '1', '?', '?', '?', '?']
# ['8', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L23,', "mitochondrial'", '18499.500', '1', '?', '?', '?', '?']
# 9  polymer     nat '54S ribosomal protein L38, mitochondrial'         14929.664   1   ? ? ? ?
#
# ['9', 'polymer', 'nat', "'54S ribosomal protein L38, mitochondrial'", '14929.664', '1', '?', '?', '?', '?']
# ['9', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L38,', "mitochondrial'", '14929.664', '1', '?', '?', '?', '?']
# 10 polymer     nat '54S ribosomal protein L10, mitochondrial'         36414.527   1   ? ? ? ?
#
# ['10', 'polymer', 'nat', "'54S ribosomal protein L10, mitochondrial'", '36414.527', '1', '?', '?', '?', '?']
# ['10', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L10,', "mitochondrial'", '36414.527', '1', '?', '?', '?', '?']
# 11 polymer     nat '54S ribosomal protein L16, mitochondrial'         26569.025   1   ? ? ? ?
#
# ['11', 'polymer', 'nat', "'54S ribosomal protein L16, mitochondrial'", '26569.025', '1', '?', '?', '?', '?']
# ['11', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L16,', "mitochondrial'", '26569.025', '1', '?', '?', '?', '?']
# 12 polymer     nat '54S ribosomal protein L8, mitochondrial'          26989.383   1   ? ? ? ?
#
# ['12', 'polymer', 'nat', "'54S ribosomal protein L8, mitochondrial'", '26989.383', '1', '?', '?', '?', '?']
# ['12', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L8,', "mitochondrial'", '26989.383', '1', '?', '?', '?', '?']
# 13 polymer     nat '54S ribosomal protein IMG1, mitochondrial'        19428.787   1   ? ? ? ?
#
# ['13', 'polymer', 'nat', "'54S ribosomal protein IMG1, mitochondrial'", '19428.787', '1', '?', '?', '?', '?']
# ['13', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'IMG1,', "mitochondrial'", '19428.787', '1', '?', '?', '?', '?']
# 14 polymer     nat '54S ribosomal protein L49, mitochondrial'         18420.539   1   ? ? ? ?
#
# ['14', 'polymer', 'nat', "'54S ribosomal protein L49, mitochondrial'", '18420.539', '1', '?', '?', '?', '?']
# ['14', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L49,', "mitochondrial'", '18420.539', '1', '?', '?', '?', '?']
# 15 polymer     nat '54S ribosomal protein L22, mitochondrial'         34957.363   1   ? ? ? ?
#
# ['15', 'polymer', 'nat', "'54S ribosomal protein L22, mitochondrial'", '34957.363', '1', '?', '?', '?', '?']
# ['15', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L22,', "mitochondrial'", '34957.363', '1', '?', '?', '?', '?']
# 16 polymer     nat '54S ribosomal protein L41, mitochondrial'         30616.221   1   ? ? ? ?
#
# ['16', 'polymer', 'nat', "'54S ribosomal protein L41, mitochondrial'", '30616.221', '1', '?', '?', '?', '?']
# ['16', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L41,', "mitochondrial'", '30616.221', '1', '?', '?', '?', '?']
# 17 polymer     nat '54S ribosomal protein L40, mitochondrial'         33808.039   1   ? ? ? ?
#
# ['17', 'polymer', 'nat', "'54S ribosomal protein L40, mitochondrial'", '33808.039', '1', '?', '?', '?', '?']
# ['17', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L40,', "mitochondrial'", '33808.039', '1', '?', '?', '?', '?']
# 18 polymer     nat '54S ribosomal protein L2, mitochondrial'          43310.684   1   ? ? ? ?
#
# ['18', 'polymer', 'nat', "'54S ribosomal protein L2, mitochondrial'", '43310.684', '1', '?', '?', '?', '?']
# ['18', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L2,', "mitochondrial'", '43310.684', '1', '?', '?', '?', '?']
# 19 polymer     nat '54S ribosomal protein L24, mitochondrial'         30109.250   1   ? ? ? ?
#
# ['19', 'polymer', 'nat', "'54S ribosomal protein L24, mitochondrial'", '30109.250', '1', '?', '?', '?', '?']
# ['19', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L24,', "mitochondrial'", '30109.250', '1', '?', '?', '?', '?']
# 20 polymer     nat '54S ribosomal protein L4, mitochondrial'          37019.922   1   ? ? ? ?
#
# ['20', 'polymer', 'nat', "'54S ribosomal protein L4, mitochondrial'", '37019.922', '1', '?', '?', '?', '?']
# ['20', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L4,', "mitochondrial'", '37019.922', '1', '?', '?', '?', '?']
# 21 polymer     nat '54S ribosomal protein L33, mitochondrial'         9549.274    1   ? ? ? ?
#
# ['21', 'polymer', 'nat', "'54S ribosomal protein L33, mitochondrial'", '9549.274', '1', '?', '?', '?', '?']
# ['21', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L33,', "mitochondrial'", '9549.274', '1', '?', '?', '?', '?']
# 22 polymer     nat '54S ribosomal protein L36, mitochondrial'         20125.756   1   ? ? ? ?
#
# ['22', 'polymer', 'nat', "'54S ribosomal protein L36, mitochondrial'", '20125.756', '1', '?', '?', '?', '?']
# ['22', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L36,', "mitochondrial'", '20125.756', '1', '?', '?', '?', '?']
# 23 polymer     nat '54S ribosomal protein L32, mitochondrial'         21483.059   1   ? ? ? ?
#
# ['23', 'polymer', 'nat', "'54S ribosomal protein L32, mitochondrial'", '21483.059', '1', '?', '?', '?', '?']
# ['23', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L32,', "mitochondrial'", '21483.059', '1', '?', '?', '?', '?']
# 24 polymer     nat '54S ribosomal protein L39, mitochondrial'         7992.650    1   ? ? ? ?
#
# ['24', 'polymer', 'nat', "'54S ribosomal protein L39, mitochondrial'", '7992.650', '1', '?', '?', '?', '?']
# ['24', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L39,', "mitochondrial'", '7992.650', '1', '?', '?', '?', '?']
# 25 polymer     nat '54S ribosomal protein L34, mitochondrial'         12054.304   1   ? ? ? ?
#
# ['25', 'polymer', 'nat', "'54S ribosomal protein L34, mitochondrial'", '12054.304', '1', '?', '?', '?', '?']
# ['25', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L34,', "mitochondrial'", '12054.304', '1', '?', '?', '?', '?']
# 26 polymer     nat 'mitochondrial ribosomal protein YNL122C'          13276.667   1   ? ? ? ?
#
# ['26', 'polymer', 'nat', "'mitochondrial ribosomal protein YNL122C'", '13276.667', '1', '?', '?', '?', '?']
# ['26', 'polymer', 'nat', "'mitochondrial", 'ribosomal', 'protein', "YNL122C'", '13276.667', '1', '?', '?', '?', '?']
# 27 polymer     nat '54S ribosomal protein RTC6, mitochondrial'        10718.978   1   ? ? ? ?
#
# ['27', 'polymer', 'nat', "'54S ribosomal protein RTC6, mitochondrial'", '10718.978', '1', '?', '?', '?', '?']
# ['27', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'RTC6,', "mitochondrial'", '10718.978', '1', '?', '?', '?', '?']
# 28 polymer     nat '54S ribosomal protein L35, mitochondrial'         42886.059   1   ? ? ? ?
#
# ['28', 'polymer', 'nat', "'54S ribosomal protein L35, mitochondrial'", '42886.059', '1', '?', '?', '?', '?']
# ['28', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L35,', "mitochondrial'", '42886.059', '1', '?', '?', '?', '?']
# 29 polymer     nat '54S ribosomal protein L28, mitochondrial'         17373.252   1   ? ? ? ?
#
# ['29', 'polymer', 'nat', "'54S ribosomal protein L28, mitochondrial'", '17373.252', '1', '?', '?', '?', '?']
# ['29', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L28,', "mitochondrial'", '17373.252', '1', '?', '?', '?', '?']
# 30 polymer     nat '54S ribosomal protein L27, mitochondrial'         16521.102   1   ? ? ? ?
#
# ['30', 'polymer', 'nat', "'54S ribosomal protein L27, mitochondrial'", '16521.102', '1', '?', '?', '?', '?']
# ['30', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L27,', "mitochondrial'", '16521.102', '1', '?', '?', '?', '?']
# 31 polymer     nat '54S ribosomal protein L51, mitochondrial'         16153.749   1   ? ? ? ?
#
# ['31', 'polymer', 'nat', "'54S ribosomal protein L51, mitochondrial'", '16153.749', '1', '?', '?', '?', '?']
# ['31', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L51,', "mitochondrial'", '16153.749', '1', '?', '?', '?', '?']
# 32 polymer     nat '54S ribosomal protein L3, mitochondrial'          44058.742   1   ? ? ? ?
#
# ['32', 'polymer', 'nat', "'54S ribosomal protein L3, mitochondrial'", '44058.742', '1', '?', '?', '?', '?']
# ['32', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L3,', "mitochondrial'", '44058.742', '1', '?', '?', '?', '?']
# 33 polymer     nat '54S ribosomal protein L17, mitochondrial'         32261.740   1   ? ? ? ?
#
# ['33', 'polymer', 'nat', "'54S ribosomal protein L17, mitochondrial'", '32261.740', '1', '?', '?', '?', '?']
# ['33', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L17,', "mitochondrial'", '32261.740', '1', '?', '?', '?', '?']
# 34 polymer     nat '54S ribosomal protein IMG2, mitochondrial'        16406.219   1   ? ? ? ?
#
# ['34', 'polymer', 'nat', "'54S ribosomal protein IMG2, mitochondrial'", '16406.219', '1', '?', '?', '?', '?']
# ['34', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'IMG2,', "mitochondrial'", '16406.219', '1', '?', '?', '?', '?']
# 35 polymer     nat '54S ribosomal protein L13, mitochondrial'         30317.365   1   ? ? ? ?
#
# ['35', 'polymer', 'nat', "'54S ribosomal protein L13, mitochondrial'", '30317.365', '1', '?', '?', '?', '?']
# ['35', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L13,', "mitochondrial'", '30317.365', '1', '?', '?', '?', '?']
# 36 polymer     nat '54S ribosomal protein L15, mitochondrial'         28148.459   1   ? ? ? ?
#
# ['36', 'polymer', 'nat', "'54S ribosomal protein L15, mitochondrial'", '28148.459', '1', '?', '?', '?', '?']
# ['36', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L15,', "mitochondrial'", '28148.459', '1', '?', '?', '?', '?']
# 37 polymer     nat '54S ribosomal protein L20, mitochondrial'         22431.871   1   ? ? ? ?
#
# ['37', 'polymer', 'nat', "'54S ribosomal protein L20, mitochondrial'", '22431.871', '1', '?', '?', '?', '?']
# ['37', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L20,', "mitochondrial'", '22431.871', '1', '?', '?', '?', '?']
# 38 polymer     nat '54S ribosomal protein L25, mitochondrial'         18626.977   1   ? ? ? ?
#
# ['38', 'polymer', 'nat', "'54S ribosomal protein L25, mitochondrial'", '18626.977', '1', '?', '?', '?', '?']
# ['38', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L25,', "mitochondrial'", '18626.977', '1', '?', '?', '?', '?']
# 39 polymer     nat '54S ribosomal protein L31, mitochondrial'         15555.466   1   ? ? ? ?
#
# ['39', 'polymer', 'nat', "'54S ribosomal protein L31, mitochondrial'", '15555.466', '1', '?', '?', '?', '?']
# ['39', 'polymer', 'nat', "'54S", 'ribosomal', 'protein', 'L31,', "mitochondrial'", '15555.466', '1', '?', '?', '?', '?']
# 40 polymer     nat 'Mitochondrial homologous recombination protein 1' 26937.762   1   ? ? ? ?
#
# ['40', 'polymer', 'nat', "'Mitochondrial homologous recombination protein 1'", '26937.762', '1', '?', '?', '?', '?']
# ['40', 'polymer', 'nat', "'Mitochondrial", 'homologous', 'recombination', 'protein', "1'", '26937.762', '1', '?', '?', '?', '?']
# 41 polymer     nat 'E-site tRNA'                                      6451.927    1   ? ? ? ?
#
# ['41', 'polymer', 'nat', "'E-site tRNA'", '6451.927', '1', '?', '?', '?', '?']
# ['41', 'polymer', 'nat', "'E-site", "tRNA'", '6451.927', '1', '?', '?', '?', '?']
# 42 non-polymer syn 'MAGNESIUM ION'                                    24.305      110 ? ? ? ?
#
# ['42', 'non-polymer', 'syn', "'MAGNESIUM ION'", '24.305', '110', '?', '?', '?', '?']
# ['42', 'non-polymer', 'syn', "'MAGNESIUM", "ION'", '24.305', '110', '?', '?', '?', '?']
# 43 non-polymer syn 'SODIUM ION'                                       22.990      1   ? ? ? ?
#
# ['43', 'non-polymer', 'syn', "'SODIUM ION'", '22.990', '1', '?', '?', '?', '?']
# ['43', 'non-polymer', 'syn', "'SODIUM", "ION'", '22.990', '1', '?', '?', '?', '?']
# 44 non-polymer syn 'ZINC ION'                                         65.409      2   ? ? ? ?
#
# ['44', 'non-polymer', 'syn', "'ZINC ION'", '65.409', '2', '?', '?', '?', '?']
# ['44', 'non-polymer', 'syn', "'ZINC", "ION'", '65.409', '2', '?', '?', '?', '?']
# 5  'YmL5, YmL7'
#
# ['5', "'YmL5, YmL7'"]
# ['5', "'YmL5,", "YmL7'"]
# 9  'YmL38, 54S ribosomal protein L34, mitochondrial, YmL34'
#
# ['9', "'YmL38, 54S ribosomal protein L34, mitochondrial, YmL34'"]
# ['9', "'YmL38,", '54S', 'ribosomal', 'protein', 'L34,', 'mitochondrial,', "YmL34'"]
# 13 'Integrity of mitochondrial genome protein 1, PetCR46'
#
# ['13', "'Integrity of mitochondrial genome protein 1, PetCR46'"]
# ['13', "'Integrity", 'of', 'mitochondrial', 'genome', 'protein', '1,', "PetCR46'"]
# 18 'YMR6, YmL2'
#
# ['18', "'YMR6, YmL2'"]
# ['18', "'YMR6,", "YmL2'"]
# 27 'Restriction of telomere capping protein 6, Translation associated element 4'
#
# ['27', "'Restriction of telomere capping protein 6, Translation associated element 4'"]
# ['27', "'Restriction", 'of', 'telomere', 'capping', 'protein', '6,', 'Translation', 'associated', 'element', "4'"]
# 34 'Integrity of mitochondrial genome protein 2'
#
# ['34', "'Integrity of mitochondrial genome protein 2'"]
# ['34', "'Integrity", 'of', 'mitochondrial', 'genome', 'protein', "2'"]
# 40 'Cross-linked transcription component 1'
#
# ['40', "'Cross-linked transcription component 1'"]
# ['40', "'Cross-linked", 'transcription', 'component', "1'"]
# 1  1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['1', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['1', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 2  1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['2', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['2', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 3  1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['3', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['3', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 4  1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['4', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['4', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 5  1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['5', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['5', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 6  1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['6', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['6', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 7  1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['7', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['7', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 8  1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['8', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['8', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 9  1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['9', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['9', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 10 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['10', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['10', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 11 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['11', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['11', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 12 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['12', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['12', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 13 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['13', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['13', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 14 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['14', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['14', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 15 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['15', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['15', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 16 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['16', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['16', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 17 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['17', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['17', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 18 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['18', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['18', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 19 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['19', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['19', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 20 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['20', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['20', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 21 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['21', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['21', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 22 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['22', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['22', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 23 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['23', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['23', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 24 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['24', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['24', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 25 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['25', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['25', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 26 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['26', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['26', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 27 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['27', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['27', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 28 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['28', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['28', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 29 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['29', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['29', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 30 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['30', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['30', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 31 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['31', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['31', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 32 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['32', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['32', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 33 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['33', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['33', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 34 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['34', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['34', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 35 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['35', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['35', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 36 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['36', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['36', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 37 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['37', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['37', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 38 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['38', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['38', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 39 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['39', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['39', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 40 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['40', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['40', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# 41 1 sample ? ? yeast 'Saccharomyces cerevisiae' 4932 ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# ['41', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# ['41', '1', 'sample', '?', '?', 'yeast', "'Saccharomyces", "cerevisiae'", '4932', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# A   'RNA linking'       y "ADENOSINE-5'-MONOPHOSPHATE" ? 'C10 H14 N5 O7 P' 347.221
#
# ['A', "'RNA linking'", 'y', '"ADENOSINE-5\'-MONOPHOSPHATE"', '?', "'C10 H14 N5 O7 P'", '347.221']
# ['A', "'RNA", "linking'", 'y', '"ADENOSINE-5\'-MONOPHOSPHATE"', '?', "'C10", 'H14', 'N5', 'O7', "P'", '347.221']
# ALA 'L-peptide linking' y ALANINE                      ? 'C3 H7 N O2'      89.093
#
# ['ALA', "'L-peptide linking'", 'y', 'ALANINE', '?', "'C3 H7 N O2'", '89.093']
# ['ALA', "'L-peptide", "linking'", 'y', 'ALANINE', '?', "'C3", 'H7', 'N', "O2'", '89.093']
# ARG 'L-peptide linking' y ARGININE                     ? 'C6 H15 N4 O2 1'  175.209
#
# ['ARG', "'L-peptide linking'", 'y', 'ARGININE', '?', "'C6 H15 N4 O2 1'", '175.209']
# ['ARG', "'L-peptide", "linking'", 'y', 'ARGININE', '?', "'C6", 'H15', 'N4', 'O2', "1'", '175.209']
# ASN 'L-peptide linking' y ASPARAGINE                   ? 'C4 H8 N2 O3'     132.118
#
# ['ASN', "'L-peptide linking'", 'y', 'ASPARAGINE', '?', "'C4 H8 N2 O3'", '132.118']
# ['ASN', "'L-peptide", "linking'", 'y', 'ASPARAGINE', '?', "'C4", 'H8', 'N2', "O3'", '132.118']
# ASP 'L-peptide linking' y 'ASPARTIC ACID'              ? 'C4 H7 N O4'      133.103
#
# ['ASP', "'L-peptide linking'", 'y', "'ASPARTIC ACID'", '?', "'C4 H7 N O4'", '133.103']
# ['ASP', "'L-peptide", "linking'", 'y', "'ASPARTIC", "ACID'", '?', "'C4", 'H7', 'N', "O4'", '133.103']
# C   'RNA linking'       y "CYTIDINE-5'-MONOPHOSPHATE"  ? 'C9 H14 N3 O8 P'  323.197
#
# ['C', "'RNA linking'", 'y', '"CYTIDINE-5\'-MONOPHOSPHATE"', '?', "'C9 H14 N3 O8 P'", '323.197']
# ['C', "'RNA", "linking'", 'y', '"CYTIDINE-5\'-MONOPHOSPHATE"', '?', "'C9", 'H14', 'N3', 'O8', "P'", '323.197']
# CYS 'L-peptide linking' y CYSTEINE                     ? 'C3 H7 N O2 S'    121.158
#
# ['CYS', "'L-peptide linking'", 'y', 'CYSTEINE', '?', "'C3 H7 N O2 S'", '121.158']
# ['CYS', "'L-peptide", "linking'", 'y', 'CYSTEINE', '?', "'C3", 'H7', 'N', 'O2', "S'", '121.158']
# G   'RNA linking'       y "GUANOSINE-5'-MONOPHOSPHATE" ? 'C10 H14 N5 O8 P' 363.221
#
# ['G', "'RNA linking'", 'y', '"GUANOSINE-5\'-MONOPHOSPHATE"', '?', "'C10 H14 N5 O8 P'", '363.221']
# ['G', "'RNA", "linking'", 'y', '"GUANOSINE-5\'-MONOPHOSPHATE"', '?', "'C10", 'H14', 'N5', 'O8', "P'", '363.221']
# GLN 'L-peptide linking' y GLUTAMINE                    ? 'C5 H10 N2 O3'    146.144
#
# ['GLN', "'L-peptide linking'", 'y', 'GLUTAMINE', '?', "'C5 H10 N2 O3'", '146.144']
# ['GLN', "'L-peptide", "linking'", 'y', 'GLUTAMINE', '?', "'C5", 'H10', 'N2', "O3'", '146.144']
# GLU 'L-peptide linking' y 'GLUTAMIC ACID'              ? 'C5 H9 N O4'      147.129
#
# ['GLU', "'L-peptide linking'", 'y', "'GLUTAMIC ACID'", '?', "'C5 H9 N O4'", '147.129']
# ['GLU', "'L-peptide", "linking'", 'y', "'GLUTAMIC", "ACID'", '?', "'C5", 'H9', 'N', "O4'", '147.129']
# GLY 'peptide linking'   y GLYCINE                      ? 'C2 H5 N O2'      75.067
#
# ['GLY', "'peptide linking'", 'y', 'GLYCINE', '?', "'C2 H5 N O2'", '75.067']
# ['GLY', "'peptide", "linking'", 'y', 'GLYCINE', '?', "'C2", 'H5', 'N', "O2'", '75.067']
# HIS 'L-peptide linking' y HISTIDINE                    ? 'C6 H10 N3 O2 1'  156.162
#
# ['HIS', "'L-peptide linking'", 'y', 'HISTIDINE', '?', "'C6 H10 N3 O2 1'", '156.162']
# ['HIS', "'L-peptide", "linking'", 'y', 'HISTIDINE', '?', "'C6", 'H10', 'N3', 'O2', "1'", '156.162']
# ILE 'L-peptide linking' y ISOLEUCINE                   ? 'C6 H13 N O2'     131.173
#
# ['ILE', "'L-peptide linking'", 'y', 'ISOLEUCINE', '?', "'C6 H13 N O2'", '131.173']
# ['ILE', "'L-peptide", "linking'", 'y', 'ISOLEUCINE', '?', "'C6", 'H13', 'N', "O2'", '131.173']
# LEU 'L-peptide linking' y LEUCINE                      ? 'C6 H13 N O2'     131.173
#
# ['LEU', "'L-peptide linking'", 'y', 'LEUCINE', '?', "'C6 H13 N O2'", '131.173']
# ['LEU', "'L-peptide", "linking'", 'y', 'LEUCINE', '?', "'C6", 'H13', 'N', "O2'", '131.173']
# LYS 'L-peptide linking' y LYSINE                       ? 'C6 H15 N2 O2 1'  147.195
#
# ['LYS', "'L-peptide linking'", 'y', 'LYSINE', '?', "'C6 H15 N2 O2 1'", '147.195']
# ['LYS', "'L-peptide", "linking'", 'y', 'LYSINE', '?', "'C6", 'H15', 'N2', 'O2', "1'", '147.195']
# MET 'L-peptide linking' y METHIONINE                   ? 'C5 H11 N O2 S'   149.211
#
# ['MET', "'L-peptide linking'", 'y', 'METHIONINE', '?', "'C5 H11 N O2 S'", '149.211']
# ['MET', "'L-peptide", "linking'", 'y', 'METHIONINE', '?', "'C5", 'H11', 'N', 'O2', "S'", '149.211']
# MG  non-polymer         . 'MAGNESIUM ION'              ? 'Mg 2'            24.305
#
# ['MG', 'non-polymer', '.', "'MAGNESIUM ION'", '?', "'Mg 2'", '24.305']
# ['MG', 'non-polymer', '.', "'MAGNESIUM", "ION'", '?', "'Mg", "2'", '24.305']
# NA  non-polymer         . 'SODIUM ION'                 ? 'Na 1'            22.990
#
# ['NA', 'non-polymer', '.', "'SODIUM ION'", '?', "'Na 1'", '22.990']
# ['NA', 'non-polymer', '.', "'SODIUM", "ION'", '?', "'Na", "1'", '22.990']
# PHE 'L-peptide linking' y PHENYLALANINE                ? 'C9 H11 N O2'     165.189
#
# ['PHE', "'L-peptide linking'", 'y', 'PHENYLALANINE', '?', "'C9 H11 N O2'", '165.189']
# ['PHE', "'L-peptide", "linking'", 'y', 'PHENYLALANINE', '?', "'C9", 'H11', 'N', "O2'", '165.189']
# PRO 'L-peptide linking' y PROLINE                      ? 'C5 H9 N O2'      115.130
#
# ['PRO', "'L-peptide linking'", 'y', 'PROLINE', '?', "'C5 H9 N O2'", '115.130']
# ['PRO', "'L-peptide", "linking'", 'y', 'PROLINE', '?', "'C5", 'H9', 'N', "O2'", '115.130']
# SER 'L-peptide linking' y SERINE                       ? 'C3 H7 N O3'      105.093
#
# ['SER', "'L-peptide linking'", 'y', 'SERINE', '?', "'C3 H7 N O3'", '105.093']
# ['SER', "'L-peptide", "linking'", 'y', 'SERINE', '?', "'C3", 'H7', 'N', "O3'", '105.093']
# THR 'L-peptide linking' y THREONINE                    ? 'C4 H9 N O3'      119.119
#
# ['THR', "'L-peptide linking'", 'y', 'THREONINE', '?', "'C4 H9 N O3'", '119.119']
# ['THR', "'L-peptide", "linking'", 'y', 'THREONINE', '?', "'C4", 'H9', 'N', "O3'", '119.119']
# TRP 'L-peptide linking' y TRYPTOPHAN                   ? 'C11 H12 N2 O2'   204.225
#
# ['TRP', "'L-peptide linking'", 'y', 'TRYPTOPHAN', '?', "'C11 H12 N2 O2'", '204.225']
# ['TRP', "'L-peptide", "linking'", 'y', 'TRYPTOPHAN', '?', "'C11", 'H12', 'N2', "O2'", '204.225']
# TYR 'L-peptide linking' y TYROSINE                     ? 'C9 H11 N O3'     181.189
#
# ['TYR', "'L-peptide linking'", 'y', 'TYROSINE', '?', "'C9 H11 N O3'", '181.189']
# ['TYR', "'L-peptide", "linking'", 'y', 'TYROSINE', '?', "'C9", 'H11', 'N', "O3'", '181.189']
# U   'RNA linking'       y "URIDINE-5'-MONOPHOSPHATE"   ? 'C9 H13 N2 O9 P'  324.181
#
# ['U', "'RNA linking'", 'y', '"URIDINE-5\'-MONOPHOSPHATE"', '?', "'C9 H13 N2 O9 P'", '324.181']
# ['U', "'RNA", "linking'", 'y', '"URIDINE-5\'-MONOPHOSPHATE"', '?', "'C9", 'H13', 'N2', 'O9', "P'", '324.181']
# VAL 'L-peptide linking' y VALINE                       ? 'C5 H11 N O2'     117.146
#
# ['VAL', "'L-peptide linking'", 'y', 'VALINE', '?', "'C5 H11 N O2'", '117.146']
# ['VAL', "'L-peptide", "linking'", 'y', 'VALINE', '?', "'C5", 'H11', 'N', "O2'", '117.146']
# ZN  non-polymer         . 'ZINC ION'                   ? 'Zn 2'            65.409
#
# ['ZN', 'non-polymer', '.', "'ZINC ION'", '?', "'Zn 2'", '65.409']
# ['ZN', 'non-polymer', '.', "'ZINC", "ION'", '?', "'Zn", "2'", '65.409']
# r_bond_refined_d             121015 0.006  0.015  'ELECTRON MICROSCOPY' ? ?
#
# ['r_bond_refined_d', '121015', '0.006', '0.015', "'ELECTRON MICROSCOPY'", '?', '?']
# ['r_bond_refined_d', '121015', '0.006', '0.015', "'ELECTRON", "MICROSCOPY'", '?', '?']
# r_bond_other_d               79796  0.002  0.020  'ELECTRON MICROSCOPY' ? ?
#
# ['r_bond_other_d', '79796', '0.002', '0.020', "'ELECTRON MICROSCOPY'", '?', '?']
# ['r_bond_other_d', '79796', '0.002', '0.020', "'ELECTRON", "MICROSCOPY'", '?', '?']
# r_ext_dist_refined_d         56648  0.579  0.071  'ELECTRON MICROSCOPY' ? ?
#
# ['r_ext_dist_refined_d', '56648', '0.579', '0.071', "'ELECTRON MICROSCOPY'", '?', '?']
# ['r_ext_dist_refined_d', '56648', '0.579', '0.071', "'ELECTRON", "MICROSCOPY'", '?', '?']
# r_angle_refined_deg          174274 0.999  1.574  'ELECTRON MICROSCOPY' ? ?
#
# ['r_angle_refined_deg', '174274', '0.999', '1.574', "'ELECTRON MICROSCOPY'", '?', '?']
# ['r_angle_refined_deg', '174274', '0.999', '1.574', "'ELECTRON", "MICROSCOPY'", '?', '?']
# r_angle_other_deg            187243 1.095  3.000  'ELECTRON MICROSCOPY' ? ?
#
# ['r_angle_other_deg', '187243', '1.095', '3.000', "'ELECTRON MICROSCOPY'", '?', '?']
# ['r_angle_other_deg', '187243', '1.095', '3.000', "'ELECTRON", "MICROSCOPY'", '?', '?']
# r_dihedral_angle_1_deg       7656   18.535 6.338  'ELECTRON MICROSCOPY' ? ?
#
# ['r_dihedral_angle_1_deg', '7656', '18.535', '6.338', "'ELECTRON MICROSCOPY'", '?', '?']
# ['r_dihedral_angle_1_deg', '7656', '18.535', '6.338', "'ELECTRON", "MICROSCOPY'", '?', '?']
# r_dihedral_angle_2_deg       2295   33.500 22.784 'ELECTRON MICROSCOPY' ? ?
#
# ['r_dihedral_angle_2_deg', '2295', '33.500', '22.784', "'ELECTRON MICROSCOPY'", '?', '?']
# ['r_dihedral_angle_2_deg', '2295', '33.500', '22.784', "'ELECTRON", "MICROSCOPY'", '?', '?']
# r_dihedral_angle_3_deg       9868   19.492 15.000 'ELECTRON MICROSCOPY' ? ?
#
# ['r_dihedral_angle_3_deg', '9868', '19.492', '15.000', "'ELECTRON MICROSCOPY'", '?', '?']
# ['r_dihedral_angle_3_deg', '9868', '19.492', '15.000', "'ELECTRON", "MICROSCOPY'", '?', '?']
# r_dihedral_angle_4_deg       460    15.808 15.000 'ELECTRON MICROSCOPY' ? ?
#
# ['r_dihedral_angle_4_deg', '460', '15.808', '15.000', "'ELECTRON MICROSCOPY'", '?', '?']
# ['r_dihedral_angle_4_deg', '460', '15.808', '15.000', "'ELECTRON", "MICROSCOPY'", '?', '?']
# r_chiral_restr               19375  0.238  0.206  'ELECTRON MICROSCOPY' ? ?
#
# ['r_chiral_restr', '19375', '0.238', '0.206', "'ELECTRON MICROSCOPY'", '?', '?']
# ['r_chiral_restr', '19375', '0.238', '0.206', "'ELECTRON", "MICROSCOPY'", '?', '?']
# r_gen_planes_refined         91779  0.005  0.020  'ELECTRON MICROSCOPY' ? ?
#
# ['r_gen_planes_refined', '91779', '0.005', '0.020', "'ELECTRON MICROSCOPY'", '?', '?']
# ['r_gen_planes_refined', '91779', '0.005', '0.020', "'ELECTRON", "MICROSCOPY'", '?', '?']
# r_gen_planes_other           26185  0.001  0.020  'ELECTRON MICROSCOPY' ? ?
#
# ['r_gen_planes_other', '26185', '0.001', '0.020', "'ELECTRON MICROSCOPY'", '?', '?']
# ['r_gen_planes_other', '26185', '0.001', '0.020', "'ELECTRON", "MICROSCOPY'", '?', '?']
# r_nbd_refined                22881  0.183  0.200  'ELECTRON MICROSCOPY' ? ?
#
# ['r_nbd_refined', '22881', '0.183', '0.200', "'ELECTRON MICROSCOPY'", '?', '?']
# ['r_nbd_refined', '22881', '0.183', '0.200', "'ELECTRON", "MICROSCOPY'", '?', '?']
# r_symmetry_nbd_other         85963  0.195  0.200  'ELECTRON MICROSCOPY' ? ?
#
# ['r_symmetry_nbd_other', '85963', '0.195', '0.200', "'ELECTRON MICROSCOPY'", '?', '?']
# ['r_symmetry_nbd_other', '85963', '0.195', '0.200', "'ELECTRON", "MICROSCOPY'", '?', '?']
# r_nbtor_refined              48552  0.215  0.200  'ELECTRON MICROSCOPY' ? ?
#
# ['r_nbtor_refined', '48552', '0.215', '0.200', "'ELECTRON MICROSCOPY'", '?', '?']
# ['r_nbtor_refined', '48552', '0.215', '0.200', "'ELECTRON", "MICROSCOPY'", '?', '?']
# r_symmetry_nbtor_other       44744  0.074  0.200  'ELECTRON MICROSCOPY' ? ?
#
# ['r_symmetry_nbtor_other', '44744', '0.074', '0.200', "'ELECTRON MICROSCOPY'", '?', '?']
# ['r_symmetry_nbtor_other', '44744', '0.074', '0.200', "'ELECTRON", "MICROSCOPY'", '?', '?']
# r_xyhbond_nbd_refined        1959   0.184  0.200  'ELECTRON MICROSCOPY' ? ?
#
# ['r_xyhbond_nbd_refined', '1959', '0.184', '0.200', "'ELECTRON MICROSCOPY'", '?', '?']
# ['r_xyhbond_nbd_refined', '1959', '0.184', '0.200', "'ELECTRON", "MICROSCOPY'", '?', '?']
# r_symmetry_xyhbond_nbd_other 36     0.069  0.200  'ELECTRON MICROSCOPY' ? ?
#
# ['r_symmetry_xyhbond_nbd_other', '36', '0.069', '0.200', "'ELECTRON MICROSCOPY'", '?', '?']
# ['r_symmetry_xyhbond_nbd_other', '36', '0.069', '0.200', "'ELECTRON", "MICROSCOPY'", '?', '?']
# r_metal_ion_refined          4      0.097  0.200  'ELECTRON MICROSCOPY' ? ?
#
# ['r_metal_ion_refined', '4', '0.097', '0.200', "'ELECTRON MICROSCOPY'", '?', '?']
# ['r_metal_ion_refined', '4', '0.097', '0.200', "'ELECTRON", "MICROSCOPY'", '?', '?']
# r_paralell_plane_angle_deg   1856   4.002  1.200  'ELECTRON MICROSCOPY' ? ?
#
# ['r_paralell_plane_angle_deg', '1856', '4.002', '1.200', "'ELECTRON MICROSCOPY'", '?', '?']
# ['r_paralell_plane_angle_deg', '1856', '4.002', '1.200', "'ELECTRON", "MICROSCOPY'", '?', '?']
# r_mcbond_it                  26772  2.447  10.193 'ELECTRON MICROSCOPY' ? ?
#
# ['r_mcbond_it', '26772', '2.447', '10.193', "'ELECTRON MICROSCOPY'", '?', '?']
# ...
# ['EC6', 'Software', '?', '?', '?', '?', '3', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3361'"]
# EC7 Software ? ? ? ? 2 'BINDING SITE FOR RESIDUE MG A 3362'
#
# ['EC7', 'Software', '?', '?', '?', '?', '2', "'BINDING SITE FOR RESIDUE MG A 3362'"]
# ['EC7', 'Software', '?', '?', '?', '?', '2', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3362'"]
# EC8 Software ? ? ? ? 2 'BINDING SITE FOR RESIDUE MG A 3363'
#
# ['EC8', 'Software', '?', '?', '?', '?', '2', "'BINDING SITE FOR RESIDUE MG A 3363'"]
# ['EC8', 'Software', '?', '?', '?', '?', '2', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3363'"]
# EC9 Software ? ? ? ? 3 'BINDING SITE FOR RESIDUE MG A 3364'
#
# ['EC9', 'Software', '?', '?', '?', '?', '3', "'BINDING SITE FOR RESIDUE MG A 3364'"]
# ['EC9', 'Software', '?', '?', '?', '?', '3', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3364'"]
# FC1 Software ? ? ? ? 1 'BINDING SITE FOR RESIDUE MG A 3365'
#
# ['FC1', 'Software', '?', '?', '?', '?', '1', "'BINDING SITE FOR RESIDUE MG A 3365'"]
# ['FC1', 'Software', '?', '?', '?', '?', '1', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3365'"]
# FC2 Software ? ? ? ? 1 'BINDING SITE FOR RESIDUE MG A 3366'
#
# ['FC2', 'Software', '?', '?', '?', '?', '1', "'BINDING SITE FOR RESIDUE MG A 3366'"]
# ['FC2', 'Software', '?', '?', '?', '?', '1', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3366'"]
# FC3 Software ? ? ? ? 1 'BINDING SITE FOR RESIDUE MG A 3367'
#
# ['FC3', 'Software', '?', '?', '?', '?', '1', "'BINDING SITE FOR RESIDUE MG A 3367'"]
# ['FC3', 'Software', '?', '?', '?', '?', '1', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3367'"]
# FC4 Software ? ? ? ? 2 'BINDING SITE FOR RESIDUE MG A 3368'
#
# ['FC4', 'Software', '?', '?', '?', '?', '2', "'BINDING SITE FOR RESIDUE MG A 3368'"]
# ['FC4', 'Software', '?', '?', '?', '?', '2', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3368'"]
# FC5 Software ? ? ? ? 1 'BINDING SITE FOR RESIDUE MG A 3369'
#
# ['FC5', 'Software', '?', '?', '?', '?', '1', "'BINDING SITE FOR RESIDUE MG A 3369'"]
# ['FC5', 'Software', '?', '?', '?', '?', '1', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3369'"]
# FC6 Software ? ? ? ? 3 'BINDING SITE FOR RESIDUE MG A 3370'
#
# ['FC6', 'Software', '?', '?', '?', '?', '3', "'BINDING SITE FOR RESIDUE MG A 3370'"]
# ['FC6', 'Software', '?', '?', '?', '?', '3', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3370'"]
# FC7 Software ? ? ? ? 1 'BINDING SITE FOR RESIDUE MG A 3371'
#
# ['FC7', 'Software', '?', '?', '?', '?', '1', "'BINDING SITE FOR RESIDUE MG A 3371'"]
# ['FC7', 'Software', '?', '?', '?', '?', '1', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3371'"]
# FC8 Software ? ? ? ? 4 'BINDING SITE FOR RESIDUE MG A 3372'
#
# ['FC8', 'Software', '?', '?', '?', '?', '4', "'BINDING SITE FOR RESIDUE MG A 3372'"]
# ['FC8', 'Software', '?', '?', '?', '?', '4', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3372'"]
# FC9 Software ? ? ? ? 2 'BINDING SITE FOR RESIDUE MG A 3373'
#
# ['FC9', 'Software', '?', '?', '?', '?', '2', "'BINDING SITE FOR RESIDUE MG A 3373'"]
# ['FC9', 'Software', '?', '?', '?', '?', '2', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3373'"]
# GC1 Software ? ? ? ? 2 'BINDING SITE FOR RESIDUE MG A 3374'
#
# ['GC1', 'Software', '?', '?', '?', '?', '2', "'BINDING SITE FOR RESIDUE MG A 3374'"]
# ['GC1', 'Software', '?', '?', '?', '?', '2', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3374'"]
# GC2 Software ? ? ? ? 1 'BINDING SITE FOR RESIDUE MG A 3375'
#
# ['GC2', 'Software', '?', '?', '?', '?', '1', "'BINDING SITE FOR RESIDUE MG A 3375'"]
# ['GC2', 'Software', '?', '?', '?', '?', '1', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3375'"]
# GC3 Software ? ? ? ? 3 'BINDING SITE FOR RESIDUE MG A 3376'
#
# ['GC3', 'Software', '?', '?', '?', '?', '3', "'BINDING SITE FOR RESIDUE MG A 3376'"]
# ['GC3', 'Software', '?', '?', '?', '?', '3', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3376'"]
# GC4 Software ? ? ? ? 2 'BINDING SITE FOR RESIDUE MG A 3377'
#
# ['GC4', 'Software', '?', '?', '?', '?', '2', "'BINDING SITE FOR RESIDUE MG A 3377'"]
# ['GC4', 'Software', '?', '?', '?', '?', '2', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3377'"]
# GC5 Software ? ? ? ? 2 'BINDING SITE FOR RESIDUE MG A 3379'
#
# ['GC5', 'Software', '?', '?', '?', '?', '2', "'BINDING SITE FOR RESIDUE MG A 3379'"]
# ['GC5', 'Software', '?', '?', '?', '?', '2', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3379'"]
# GC6 Software ? ? ? ? 2 'BINDING SITE FOR RESIDUE MG A 3380'
#
# ['GC6', 'Software', '?', '?', '?', '?', '2', "'BINDING SITE FOR RESIDUE MG A 3380'"]
# ['GC6', 'Software', '?', '?', '?', '?', '2', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3380'"]
# GC7 Software ? ? ? ? 2 'BINDING SITE FOR RESIDUE MG A 3381'
#
# ['GC7', 'Software', '?', '?', '?', '?', '2', "'BINDING SITE FOR RESIDUE MG A 3381'"]
# ['GC7', 'Software', '?', '?', '?', '?', '2', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3381'"]
# GC8 Software ? ? ? ? 4 'BINDING SITE FOR RESIDUE MG A 3382'
#
# ['GC8', 'Software', '?', '?', '?', '?', '4', "'BINDING SITE FOR RESIDUE MG A 3382'"]
# ['GC8', 'Software', '?', '?', '?', '?', '4', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3382'"]
# GC9 Software ? ? ? ? 2 'BINDING SITE FOR RESIDUE MG A 3383'
#
# ['GC9', 'Software', '?', '?', '?', '?', '2', "'BINDING SITE FOR RESIDUE MG A 3383'"]
# ['GC9', 'Software', '?', '?', '?', '?', '2', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3383'"]
# HC1 Software ? ? ? ? 1 'BINDING SITE FOR RESIDUE MG A 3384'
#
# ['HC1', 'Software', '?', '?', '?', '?', '1', "'BINDING SITE FOR RESIDUE MG A 3384'"]
# ['HC1', 'Software', '?', '?', '?', '?', '1', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3384'"]
# HC2 Software ? ? ? ? 3 'BINDING SITE FOR RESIDUE MG A 3385'
#
# ['HC2', 'Software', '?', '?', '?', '?', '3', "'BINDING SITE FOR RESIDUE MG A 3385'"]
# ['HC2', 'Software', '?', '?', '?', '?', '3', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3385'"]
# HC3 Software ? ? ? ? 2 'BINDING SITE FOR RESIDUE MG A 3386'
#
# ['HC3', 'Software', '?', '?', '?', '?', '2', "'BINDING SITE FOR RESIDUE MG A 3386'"]
# ['HC3', 'Software', '?', '?', '?', '?', '2', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3386'"]
# HC4 Software ? ? ? ? 2 'BINDING SITE FOR RESIDUE MG A 3388'
#
# ['HC4', 'Software', '?', '?', '?', '?', '2', "'BINDING SITE FOR RESIDUE MG A 3388'"]
# ['HC4', 'Software', '?', '?', '?', '?', '2', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3388'"]
# HC5 Software ? ? ? ? 1 'BINDING SITE FOR RESIDUE MG A 3389'
#
# ['HC5', 'Software', '?', '?', '?', '?', '1', "'BINDING SITE FOR RESIDUE MG A 3389'"]
# ['HC5', 'Software', '?', '?', '?', '?', '1', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3389'"]
# HC6 Software ? ? ? ? 3 'BINDING SITE FOR RESIDUE MG A 3390'
#
# ['HC6', 'Software', '?', '?', '?', '?', '3', "'BINDING SITE FOR RESIDUE MG A 3390'"]
# ['HC6', 'Software', '?', '?', '?', '?', '3', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3390'"]
# HC7 Software ? ? ? ? 1 'BINDING SITE FOR RESIDUE MG A 3391'
#
# ['HC7', 'Software', '?', '?', '?', '?', '1', "'BINDING SITE FOR RESIDUE MG A 3391'"]
# ['HC7', 'Software', '?', '?', '?', '?', '1', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3391'"]
# HC8 Software ? ? ? ? 1 'BINDING SITE FOR RESIDUE MG A 3392'
#
# ['HC8', 'Software', '?', '?', '?', '?', '1', "'BINDING SITE FOR RESIDUE MG A 3392'"]
# ['HC8', 'Software', '?', '?', '?', '?', '1', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3392'"]
# HC9 Software ? ? ? ? 2 'BINDING SITE FOR RESIDUE MG A 3393'
#
# ['HC9', 'Software', '?', '?', '?', '?', '2', "'BINDING SITE FOR RESIDUE MG A 3393'"]
# ['HC9', 'Software', '?', '?', '?', '?', '2', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3393'"]
# IC1 Software ? ? ? ? 4 'BINDING SITE FOR RESIDUE MG A 3394'
#
# ['IC1', 'Software', '?', '?', '?', '?', '4', "'BINDING SITE FOR RESIDUE MG A 3394'"]
# ['IC1', 'Software', '?', '?', '?', '?', '4', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3394'"]
# IC2 Software ? ? ? ? 3 'BINDING SITE FOR RESIDUE MG A 3395'
#
# ['IC2', 'Software', '?', '?', '?', '?', '3', "'BINDING SITE FOR RESIDUE MG A 3395'"]
# ['IC2', 'Software', '?', '?', '?', '?', '3', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3395'"]
# IC3 Software ? ? ? ? 1 'BINDING SITE FOR RESIDUE MG A 3396'
#
# ['IC3', 'Software', '?', '?', '?', '?', '1', "'BINDING SITE FOR RESIDUE MG A 3396'"]
# ['IC3', 'Software', '?', '?', '?', '?', '1', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3396'"]
# IC4 Software ? ? ? ? 2 'BINDING SITE FOR RESIDUE MG A 3397'
#
# ['IC4', 'Software', '?', '?', '?', '?', '2', "'BINDING SITE FOR RESIDUE MG A 3397'"]
# ['IC4', 'Software', '?', '?', '?', '?', '2', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3397'"]
# IC5 Software ? ? ? ? 3 'BINDING SITE FOR RESIDUE MG A 3398'
#
# ['IC5', 'Software', '?', '?', '?', '?', '3', "'BINDING SITE FOR RESIDUE MG A 3398'"]
# ['IC5', 'Software', '?', '?', '?', '?', '3', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3398'"]
# IC6 Software ? ? ? ? 5 'BINDING SITE FOR RESIDUE MG A 3399'
#
# ['IC6', 'Software', '?', '?', '?', '?', '5', "'BINDING SITE FOR RESIDUE MG A 3399'"]
# ['IC6', 'Software', '?', '?', '?', '?', '5', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3399'"]
# IC7 Software ? ? ? ? 3 'BINDING SITE FOR RESIDUE MG A 3400'
#
# ['IC7', 'Software', '?', '?', '?', '?', '3', "'BINDING SITE FOR RESIDUE MG A 3400'"]
# ['IC7', 'Software', '?', '?', '?', '?', '3', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3400'"]
# IC8 Software ? ? ? ? 2 'BINDING SITE FOR RESIDUE MG A 3401'
#
# ['IC8', 'Software', '?', '?', '?', '?', '2', "'BINDING SITE FOR RESIDUE MG A 3401'"]
# ['IC8', 'Software', '?', '?', '?', '?', '2', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3401'"]
# IC9 Software ? ? ? ? 1 'BINDING SITE FOR RESIDUE MG A 3402'
#
# ['IC9', 'Software', '?', '?', '?', '?', '1', "'BINDING SITE FOR RESIDUE MG A 3402'"]
# ['IC9', 'Software', '?', '?', '?', '?', '1', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3402'"]
# JC1 Software ? ? ? ? 3 'BINDING SITE FOR RESIDUE MG A 3403'
#
# ['JC1', 'Software', '?', '?', '?', '?', '3', "'BINDING SITE FOR RESIDUE MG A 3403'"]
# ['JC1', 'Software', '?', '?', '?', '?', '3', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3403'"]
# JC2 Software ? ? ? ? 2 'BINDING SITE FOR RESIDUE MG A 3404'
#
# ['JC2', 'Software', '?', '?', '?', '?', '2', "'BINDING SITE FOR RESIDUE MG A 3404'"]
# ['JC2', 'Software', '?', '?', '?', '?', '2', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3404'"]
# JC3 Software ? ? ? ? 2 'BINDING SITE FOR RESIDUE MG A 3405'
#
# ['JC3', 'Software', '?', '?', '?', '?', '2', "'BINDING SITE FOR RESIDUE MG A 3405'"]
# ['JC3', 'Software', '?', '?', '?', '?', '2', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3405'"]
# JC4 Software ? ? ? ? 2 'BINDING SITE FOR RESIDUE MG A 3407'
#
# ['JC4', 'Software', '?', '?', '?', '?', '2', "'BINDING SITE FOR RESIDUE MG A 3407'"]
# ['JC4', 'Software', '?', '?', '?', '?', '2', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3407'"]
# JC5 Software ? ? ? ? 2 'BINDING SITE FOR RESIDUE MG A 3408'
#
# ['JC5', 'Software', '?', '?', '?', '?', '2', "'BINDING SITE FOR RESIDUE MG A 3408'"]
# ['JC5', 'Software', '?', '?', '?', '?', '2', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3408'"]
# JC6 Software ? ? ? ? 2 'BINDING SITE FOR RESIDUE MG A 3409'
#
# ['JC6', 'Software', '?', '?', '?', '?', '2', "'BINDING SITE FOR RESIDUE MG A 3409'"]
# ['JC6', 'Software', '?', '?', '?', '?', '2', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'A', "3409'"]
# JC7 Software ? ? ? ? 5 'BINDING SITE FOR RESIDUE NA B 500'
#
# ['JC7', 'Software', '?', '?', '?', '?', '5', "'BINDING SITE FOR RESIDUE NA B 500'"]
# ['JC7', 'Software', '?', '?', '?', '?', '5', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'NA', 'B', "500'"]
# JC8 Software ? ? ? ? 4 'BINDING SITE FOR RESIDUE MG N 201'
#
# ['JC8', 'Software', '?', '?', '?', '?', '4', "'BINDING SITE FOR RESIDUE MG N 201'"]
# ['JC8', 'Software', '?', '?', '?', '?', '4', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'MG', 'N', "201'"]
# JC9 Software ? ? ? ? 5 'BINDING SITE FOR RESIDUE ZN W 200'
#
# ['JC9', 'Software', '?', '?', '?', '?', '5', "'BINDING SITE FOR RESIDUE ZN W 200'"]
# ['JC9', 'Software', '?', '?', '?', '?', '5', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'ZN', 'W', "200'"]
# KC1 Software ? ? ? ? 4 'BINDING SITE FOR RESIDUE ZN 0 100'
#
# ['KC1', 'Software', '?', '?', '?', '?', '4', "'BINDING SITE FOR RESIDUE ZN 0 100'"]
# ['KC1', 'Software', '?', '?', '?', '?', '4', "'BINDING", 'SITE', 'FOR', 'RESIDUE', 'ZN', '0', "100'"]
# 1 'ENTRY CONTAINS NUMEROUS IMPROPER PEPTIDE LINKAGES.'
#
# ['1', "'ENTRY CONTAINS NUMEROUS IMPROPER PEPTIDE LINKAGES.'"]
# ['1', "'ENTRY", 'CONTAINS', 'NUMEROUS', 'IMPROPER', 'PEPTIDE', "LINKAGES.'"]
# 2 'ENTRY CONTAINS UNREALISTIC INTERATOMIC DISTANCES.'
#
# ['2', "'ENTRY CONTAINS UNREALISTIC INTERATOMIC DISTANCES.'"]
# ['2', "'ENTRY", 'CONTAINS', 'UNREALISTIC', 'INTERATOMIC', "DISTANCES.'"]
# 3 'ENTRY CONTAINS CHIRALITY ERRORS.'
#
# ['3', "'ENTRY CONTAINS CHIRALITY ERRORS.'"]
# ['3', "'ENTRY", 'CONTAINS', 'CHIRALITY', "ERRORS.'"]
# 1 'Structure model' 1 0 2014-04-09
#
# ['1', "'Structure model'", '1', '0', '2014-04-09']
# ['1', "'Structure", "model'", '1', '0', '2014-04-09']
# 2 'Structure model' 1 1 2014-07-09
#
# ['2', "'Structure model'", '1', '1', '2014-07-09']
# ['2', "'Structure", "model'", '1', '1', '2014-07-09']
# 3 'Structure model' 1 2 2014-12-10
#
# ['3', "'Structure model'", '1', '2', '2014-12-10']
# ['3', "'Structure", "model'", '1', '2', '2014-12-10']
# 4 'Structure model' 1 3 2014-12-17
#
# ['4', "'Structure model'", '1', '3', '2014-12-17']
# ['4', "'Structure", "model'", '1', '3', '2014-12-17']
# 5 'Structure model' 1 4 2018-07-18
#
# ['5', "'Structure model'", '1', '4', '2018-07-18']
# ['5', "'Structure", "model'", '1', '4', '2018-07-18']
# 1 2 'Structure model' Other
#
# ['1', '2', "'Structure model'", 'Other']
# ['1', '2', "'Structure", "model'", 'Other']
# 2 3 'Structure model' Other
#
# ['2', '3', "'Structure model'", 'Other']
# ['2', '3', "'Structure", "model'", 'Other']
# 3 4 'Structure model' Other
#
# ['3', '4', "'Structure model'", 'Other']
# ['3', '4', "'Structure", "model'", 'Other']
# 4 5 'Structure model' 'Data collection'
#
# ['4', '5', "'Structure model'", "'Data collection'"]
# ['4', '5', "'Structure", "model'", "'Data", "collection'"]
# 1 5 'Structure model' '_em_software.image_processing_id'
#
# ['1', '5', "'Structure model'", "'_em_software.image_processing_id'"]
# ['1', '5', "'Structure", "model'", "'_em_software.image_processing_id'"]
# 2 5 'Structure model' '_em_software.name'
#
# ['2', '5', "'Structure model'", "'_em_software.name'"]
# ['2', '5', "'Structure", "model'", "'_em_software.name'"]
# 1 CTFFIND 3 'CTF CORRECTION' ? ?
#
# ['1', 'CTFFIND', '3', "'CTF CORRECTION'", '?', '?']
# ['1', 'CTFFIND', '3', "'CTF", "CORRECTION'", '?', '?']
# 3J6B 'double helix'
#
# ['3J6B', "'double helix'"]
# ['3J6B', "'double", "helix'"]
# 3J6B 'a-form double helix'
#
# ['3J6B', "'a-form double helix'"]
# ['3J6B', "'a-form", 'double', "helix'"]
# 3J6B 'parallel strands'
#
# ['3J6B', "'parallel strands'"]
# ['3J6B', "'parallel", "strands'"]
# 3J6B 'hairpin loop'
#
# ['3J6B', "'hairpin loop'"]
# ['3J6B', "'hairpin", "loop'"]
# 3J6B 'bulge loop'
#
# ['3J6B', "'bulge loop'"]
# ['3J6B', "'bulge", "loop'"]
# 3J6B 'mismatched base pair'
#
# ['3J6B', "'mismatched base pair'"]
# ['3J6B', "'mismatched", 'base', "pair'"]
# 3J6B 'internal loop'
#
# ['3J6B', "'internal loop'"]
# ['3J6B', "'internal", "loop'"]
# 3J6B 'triple helix'
#
# ['3J6B', "'triple helix'"]
# ['3J6B', "'triple", "helix'"]
# 3J6B 'quadruple helix'
#
# ['3J6B', "'quadruple helix'"]
# ['3J6B', "'quadruple", "helix'"]
# 3J6B 'three-way junction'
#
# ['3J6B', "'three-way junction'"]
# ['3J6B', "'three-way", "junction'"]
# 3J6B 'four-way junction'
#
# ['3J6B', "'four-way junction'"]
# ['3J6B', "'four-way", "junction'"]
# 42 'MAGNESIUM ION' MG
#
# ['42', "'MAGNESIUM ION'", 'MG']
# ['42', "'MAGNESIUM", "ION'", 'MG']
# 43 'SODIUM ION'    NA
#
# ['43', "'SODIUM ION'", 'NA']
# ['43', "'SODIUM", "ION'", 'NA']
# 44 'ZINC ION'      ZN
#
# ['44', "'ZINC ION'", 'ZN']
# ['44', "'ZINC", "ION'", 'ZN']

# %%
line = "EMDB EMD-2566 'Electron cryo-microscopy of yeast mitochondrial large ribosomal subunit' 'associated EM volume' "

# %%
delimiters = ["'", " "]
line.split(delimiters)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 delimiters = ["'", " "]
# ----> 2 line.split(delimiters)
#
# TypeError: must be str or None, not list

# %%
def string_split(str: line):
    
    quote_in = False
    first_quote = ""
    tokens = []
    token = ""
    
    for letter in line:
        if quote_in:
            if letter != first_quote:
                token += letter
            else:
                tokens.append(token)
                token=""
                quote_in = False
        elif letter == "'" or letter == '"':
                first_quote = letter
                quote_in = True
        elif letter != " ":
            token += letter
        else:
            if len(token):
                tokens.append(token)
                token=""
                
    return tokens

# %%
line = "A   'RNA linking'       y \"ADENOSINE-5'-MONOPHOSPHATE\" ? 'C10 H14 N5 O7 P' 347.221 "
string_split(line)
# Out:
# quote_done RNA linking
# quote_done ADENOSINE-5'-MONOPHOSPHATE
# quote_done C10 H14 N5 O7 P
# ['A',
#  'RNA linking',
#  'y',
#  "ADENOSINE-5'-MONOPHOSPHATE",
#  '?',
#  'C10 H14 N5 O7 P',
#  '347.221']

# %%
# %timeit string_split(line)
# Out:
# 8.68 µs ± 148 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit string_split_cython(line)
# Out:
# 7.76 µs ± 90.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit line.split()
# Out:
# 402 ns ± 1.78 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %load_ext Cython

# %%
# %%cython -a
#
# def string_split_cython(str line):
#
#     cdef:
#         bint quote_in = False
#         list tokens = []
#         char letter
#         str token = ""
#
#     for letter in line:
#         if letter == b"'" or letter == b'"':
#             print('YO:', letter)
#         elif letter != b" ":
#             token += letter
#
#     return tokens
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 3.0.9 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_d93a39bb62b505dc317adfc30765afa79d920e62.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { color: #000000; margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.scor

# %%
line = "A   'RNA linking'       y \"ADENOSINE-5'-MONOPHOSPHATE\" ? 'C10 H14 N5 O7 P' 347.221   \n"
string_split_cython(line)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[371], line 2
#       1 line = "A   'RNA linking'       y \"ADENOSINE-5'-MONOPHOSPHATE\" ? 'C10 H14 N5 O7 P' 347.221   \n"
# ----> 2 string_split_cython(line)
#
# File _cython_magic_ee750f5b20e822f79a87b9912914635fb95d3780.pyx:6, in _cython_magic_ee750f5b20e822f79a87b9912914635fb95d3780.string_split_cython()
#
# TypeError: expected bytes, str found

# %%
# %%cython -a
#
# def string_split_cython(str line):
#
#     cdef:
#         int i
#         int quote_in = False
#         char first_quote
#         list tokens = []
#         unicode token = u""
#         char letter
#
#     first_quote = ''
#
#     for letter in line:
#         if quote_in:
#             if letter != first_quote:
#                 i = 0
#                 #token += str(letter)
#             else:
#                 #tokens.append(token)
#                 token = ""
#                 quote_in = False
#         elif letter == b"'" or letter == b'"':
#                 first_quote = letter
#                 quote_in = True
#         elif letter != b" ":
#             i=0
#             #token += str(letter)
#         else:
#             if len(token):
#                 #tokens.append(token)
#                 #print(token)
#                 token=""
#
#     return tokens
# Out:
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         char first_quote
#         list tokens = []
#         unicode token = u""
#         char letter
#
#     first_quote = ''
#                   ^
# ------------------------------------------------------------
#
# /home/murail/.cache/ipython/cython/_cython_magic_e85bb5845f6bd396c741c087dbf419773ad294bb.pyx:12:18: Unicode literals do not support coercion to C types other than Py_UNICODE/Py_UCS4 (for characters) or Py_UNICODE* (for strings).

# %%
# %%cython -a
# import cython
# from libc.string cimport strcpy, strlen
#
# @cython.boundscheck(False) # Deactivate bounds checking
# @cython.wraparound(False) # Deactivate negative indexing.
# def string_split_cython(char * line):
#
#     cdef:
#         size_t i = 0
#         int j
#         int quote_in = False
#         char first_quote = 0, letter
#         str token = ""
#         list tokens = []
#
#     for letter in line:
#         if quote_in:
#             if letter != first_quote:
#                 j = 0
#                 token += str(letter)
#             else:
#                 tokens.append(token)
#                 token = ""
#                 quote_in = False
#         elif letter == b"'" or letter == b'"':
#                 first_quote = letter
#                 quote_in = True
#         elif letter != b" ":
#             j = 0
#             token += str(letter)
#         else:
#             if len(token):
#                 tokens.append(token)
#                 token=""
#
#     return tokens
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 3.0.9 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_ee750f5b20e822f79a87b9912914635fb95d3780.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { color: #000000; margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.scor

# %%
# %%cython -a
# import cython
# from libc.string cimport strcpy, strlen
#
# @cython.wraparound(False) # Deactivate negative indexing.
# cdef bint is_space (char c):
#     if c == b" ":
#         return True
#     else:
#         return False
#
# @cython.wraparound(False) # Deactivate negative indexing.
# cdef bint is_quote (char c):
#     if c == b"'" or c ==b'"':
#         return True
#     else:
#         return False
#
# @cython.boundscheck(False) # Deactivate bounds checking
# @cython.wraparound(False) # Deactivate negative indexing.
# def string_split(str line_raw):
#
#     tmp = line_raw.encode('utf-8')
#
#     cdef:
#         int i=0, j=0, k=0, count=0, str_len
#         char first_quote
#         list split_list = []
#         char * line
#
#     line = tmp
#
#     str_len = strlen(line)
#
#     while (i<str_len) :
#
#         while (i<str_len and is_space(line[i])):
#             i += 1
#
#         if is_quote(line[i]):
#             first_quote = line[i]
#             j = i
#             i += 1
#             while (i<str_len and line[i] != first_quote):
#                 i += 1
#             i += 1
#         else:
#             j = i
#             while (i<str_len and not is_space(line[i])):
#                 i += 1
#         if i != j:
#             split_list.append(line[j:i].decode('UTF-8'))
#         i+=1
#     return split_list
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 3.0.9 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_24a166bd3e9a8eb0d198babfa9b7b6ae038a0e23.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { color: #000000; margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.scor

# %%
line
# Out:
# 'A   \'RNA linking\'       y "ADENOSINE-5\'-MONOPHOSPHATE" ? \'C10 H14 N5 O7 P\' 347.221   \n'

# %%
line_unicode = line.encode('utf-8')
tmp = string_split(line[:-1])
tmp
# Out:
# ['A',
#  "'RNA linking'",
#  'y',
#  '"ADENOSINE-5\'-MONOPHOSPHATE"',
#  '?',
#  "'C10 H14 N5 O7 P'",
#  '347.221']

# %%
# %timeit string_split(line)
# Out:
# 399 ns ± 7.2 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %timeit line_unicode.split()
# Out:
# 356 ns ± 3.8 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %timeit string_split_cython_2(line_unicode)
# Out:
# 269 ns ± 2.82 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
tmp
# Out:
# ['65',
#  '82786532108105110107105110103',
#  '121',
#  '6568697879837378694553394577797879807279838072658469',
#  '63',
#  '674948327249523278533279553280',
#  '51525546505049']

# %%
tmp[0].encode('UTF-8')
# Out:
# b'65'

# %%
string_split(line)
# Out:
# ['A',
#  'RNA linking',
#  'y',
#  "ADENOSINE-5'-MONOPHOSPHATE",
#  '?',
#  'C10 H14 N5 O7 P',
#  '347.221']
