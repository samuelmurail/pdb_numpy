# %%
import sys
import json
import numpy as np

sys.path.insert(0, "./src/")

import pdb_numpy
from pdb_numpy import analysis

# %%
analysis.__file__
# Out:
# '/home/murail/Documents/Code/pdb_numpy/./src/pdb_numpy/analysis.py'

# %%
colab_coor = pdb_numpy.Coor("src/pdb_numpy/tests/input/1rxz_11587_unrelaxed_rank_001_alphafold2_multimer_v3_model_4_seed_000.pdb")
with open("src/pdb_numpy/tests/input/1rxz_11587_scores_rank_001_alphafold2_multimer_v3_model_4_seed_000.json") as f:
    local_json = json.load(f)
pae_array = np.array(local_json["pae"])

# %%
analysis.compute_pdockQ2(colab_coor, pae_array)
# Out:
# [[0.7723798262759464], [0.7464538522725119]]

# %%
import importlib
importlib.reload(pdb_numpy)
importlib.reload(analysis)
# Out:
# <module 'pdb_numpy.analysis' from '/home/murail/Documents/Code/pdb_numpy/./src/pdb_numpy/analysis.py'>

# %%
analysis.compute_piTM(colab_coor, pae_array)
# Out:
# ['A' 'B'] (256, 256) 256
# ([0.44511699526580745], [[0.20399023734262997], [0.11672406812830069]])

# %%
1.24 * (200-15)**(1/3) -1.8
# Out:
# 5.265543826978281

# %%
import matplotlib.pyplot as plt

plt.imshow(pae_array)
plt.colorbar()
